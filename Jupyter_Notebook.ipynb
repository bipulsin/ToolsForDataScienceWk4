# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# #### Add your code below following the instructions given in the course

# %% [markdown]
# <h1>My Jupyter Notebook on IBM Watson Studio</h1>

# %% [markdown]
# <strong>Bipul Sahay</strong></br>Lead Software Technology

# %% [markdown]
# *I am interested in Data Science as I want to solve the predictability problem for healthcare professionals. Want to contribute so various professionals can rely on data to take strategic decision.*

# %% [markdown]
# <h3>This code is about adding two numbers and printing the sum using print()</h3>

# %%
print(19 + 37)
# Out:
# 56

# %% [markdown]
# 1. This is the first element of numbered list
# 2. This is the second element
# 3. This is the third element of number list
# ***
# ![rocket.jpg](attachment:93af7534-1ee3-48b6-92ff-7cc6d455443d.jpg)
# <table style="border: 1px solid black">
#     <tr><th>Cell 1</th><th>Cell 2</th><th>Cell 3</th></tr>
#     <tr><td>Cell 1</td><td>Cell 2</td><td>Cell 3</td></tr>
#     <tr><td>Cell 4</td><td>Cell 5</td><td>Cell 6</td></tr>
# </table>
